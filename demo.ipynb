# %%
import roboticstoolbox as rtb
import numpy as np
import cProfile

panda = rtb.models.Panda()

J_slow = panda.jacobe(panda.qr)

# J_fast = panda.jacobe(panda.qr,fast= True) # fast parameter wont work because it is C++ implementation and there is some kind of bridge btw py and C++

print(np.round(J_slow,2))
# print(np.round(J_fast,2))
# Out:
# [[ 0.    0.03  0.    0.3   0.    0.21 -0.  ]
#  [-0.48 -0.   -0.49  0.   -0.15  0.    0.  ]
#  [-0.    0.49 -0.   -0.47 -0.   -0.09  0.  ]
#  [ 0.1  -0.   -0.2   0.    0.91  0.    0.  ]
#  [ 0.   -1.    0.    1.    0.    1.    0.  ]
#  [-1.   -0.   -0.98  0.    0.42  0.    1.  ]]

# %%
def slow():
    for _ in range(1000):
        panda.jacobe(panda.qr)
# C++ comparison
#def fast():
#    for _ in range(1000):
#        panda.jacobe(panda.qr,fast=True)

cProfile.run("slow()")

# cProfile.run("fast()")
# Out:
#          3004 function calls in 0.001 seconds
#
#    Ordered by: standard name
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.000    0.000    0.001    0.001 1022315155.py:1(slow)
#         1    0.000    0.000    0.001    0.001 <string>:1(<module>)
#      1000    0.000    0.000    0.001    0.000 ETS.py:1244(jacobe)
#      1000    0.000    0.000    0.001    0.000 RobotKinematics.py:160(jacobe)
#         1    0.000    0.000    0.001    0.001 {built-in method builtins.exec}
#      1000    0.001    0.000    0.001    0.000 {built-in method roboticstoolbox.fknm.ETS_jacobe}
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}
