# %% [markdown]
# this is testing code for environment

# %%
import roboticstoolbox as rtb
import swift 
import numpy as np
import spatialmath as sm
import spatialgeometry as sg

# %%
#create swift instance
env = swift.Swift()
env.launch(realtime=True)

# %%
# initialise the model
panda = rtb.models.Panda()
panda.q = panda.qr

# %%
# add panda to swift
env.add(panda,robot_alpha=1, collision_alpha=0.5)

# set goal pose
Tep = panda.fkine(panda.q) * sm.SE3.Tx(0.2) * sm.SE3.Ty(0.2) * sm.SE3.Tz(0.35)

axes = sg.Axes(length=0.1,base=Tep)
env.add(axes)
# Out:
# /home/cago/intro_to_robotics/.venv/lib/python3.10/site-packages/spatialgeometry/geom/Shape.py:81: FutureWarning: base kwarg is deprecated, use pose instead
#   warn("base kwarg is deprecated, use pose instead", FutureWarning)
# 1

# %%
# Arrived at destination flag
arrived = False

# Time step

dt= 0.01

while not arrived:
    # v is a 6 vector representing the spatial error
    v, arrived = rtb.p_servo(panda.fkine(panda.q),Tep,gain=0.1,threshold=0.01)

    J = panda.jacobe(panda.q)
    
    panda.qd = np.linalg.pinv(J) @ v

    # step the environment
    env.step(dt)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[10], line 17
#      14 panda.qd = np.linalg.pinv(J) @ v
#      16 # step the environment
# ---> 17 env.step(dt)
#
# File ~/intro_to_robotics/.venv/lib/python3.10/site-packages/swift/Swift.py:244, in Swift.step(self, dt, render)
#     241     self._skipped = 1
#     243     if diff > 0:
# --> 244         time.sleep(diff)
#     246     self.last_time = time.time()
#     247 elif (time.time() - self._laststep) < self._period:
#     248     # Only render at 60 FPS
#
# KeyboardInterrupt:

# %%
# stop the browser tab from closing
env.hold()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[19], line 2
#       1 # stop the browser tab from closing
# ----> 2 env.hold()
#
# File ~/intro_to_robotics/.venv/lib/python3.10/site-packages/swift/Swift.py:466, in Swift.hold(self)
#     459 """
#     460 hold() keeps the browser tab open i.e. stops the browser tab from
#     461 closing once the main script has finished.
#     462
#     463 """
#     465 while True:
# --> 466     time.sleep(1)
#
# KeyboardInterrupt:
